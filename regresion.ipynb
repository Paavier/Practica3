# %%
#Autor: Pedro Javier Ortega Fernandez
#Titulación: Doble Grado Matemáticas e Ingeniería Informática

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
model_0_df = pd.read_csv('data/Reg_0.csv')
model_1_df = pd.read_csv('data/Reg_1.csv')
model_2_df = pd.read_csv('data/Reg_2.csv')
model_3_df = pd.read_csv('data/Reg_3.csv')
model_4_df = pd.read_csv('data/Reg_4.csv')

# %%
def calc_mae(df):
    return (df['gt'] - df['pred']).abs().mean()

# %%
def calc_mse(df):
    return ((df['gt'] - df['pred']) ** 2).mean()

# %%
def calc_medAE(df):
    return (df['gt'] - df['pred']).abs().median()

# %%
def calc_rmse(df):
    return np.sqrt(calc_mse(df))

# %%
#Metricas de modelo los modelos
datasets = {'Dataset_0' : model_0_df,
            'Dataset_1' : model_1_df,
            'Dataset_2' : model_2_df,
            'Dataset_3' : model_3_df,
            'Dataset_4' : model_4_df}

results = []

for name, df in datasets.items():
    mae = calc_mae(df)
    mse = calc_mse(df)
    medAE = calc_medAE(df)
    rmse = calc_rmse(df)
    
    results.append({
        'Dataset' : name,
        'MAE' : mae,
        'MSE' : mse,
        'medAE' : medAE,
        'RMSE' : rmse,
    })

df_metricas = pd.DataFrame(results)
print(df_metricas)
# Out:
#      Dataset        MAE         MSE      medAE       RMSE
# 0  Dataset_0   0.390447    0.244170   0.330979   0.494135
# 1  Dataset_1   3.985465   24.762891   3.256197   4.976233
# 2  Dataset_2  12.126768  232.743282  10.526147  15.255926
# 3  Dataset_3  10.000000  100.000000  10.000000  10.000000
# 4  Dataset_4   6.357652  281.846541   3.235485  16.788286

# %%
#Distribucion de datos, outliers
datagramas = [model_0_df['gt'] - model_0_df['pred'],
              model_1_df['gt'] - model_1_df['pred'],
              model_2_df['gt'] - model_2_df['pred'],
              model_3_df['gt'] - model_3_df['pred'],
              model_4_df['gt'] - model_4_df['pred']]

plt.boxplot(datagramas, labels=['Dataset_0', 'Dataset_1', 'Dataset_2', 'Dataset_3', 'Dataset_4'])
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_20920\2417331486.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(datagramas, labels=['Dataset_0', 'Dataset_1', 'Dataset_2', 'Dataset_3', 'Dataset_4'])

# %%
plt.boxplot(model_4_df['gt'] - model_4_df['pred'], label = 'Dataset_4')
plt.show()
